# %%
import pandas as pd
import requests
from dotenv import load_dotenv
import time
import json
import os

# %%
# Sign up for an API key

requests.get("https://aqs.epa.gov/data/api/signup?email=vogt.benjamin.a@gmail.com")
# Out:
# <Response [200]>

# %%
load_dotenv(dotenv_path=".env")
email = os.getenv("EMAIL")
api_key = os.getenv("API_KEY")

# %%
# Get metadata for the sampleData service

params = {
    "email": "vogt.benjamin.a@gmail.com",
    "key": api_key,
    "service": "sampleData"
}


metadata = requests.get("https://aqs.epa.gov/data/api/metaData/fieldsByService", params=params)

# %%
metadata.json()
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2025-11-13T04:50:20-05:00',
#    'url': 'https://aqs.epa.gov/data/api/metaData/fieldsByService?email=vogt.benjamin.a%40gmail.com&key=greenmouse47&service=sampleData',
#    'rows': 27}],
#  'Data': [{'field_name': 'state_code',
#    'field_description': "The FIPS code of the state in which the monitor resides.  AQS uses 2-digit or character codes that identifies one of the 50 states, U. S. territories, or Washington, DC.  For border sites, the code '80' is used for Mexico and 'CC' is used for Canada.\r\n\r\nWhen submitting transactions, a user may opt to use the code 'TT' to indicate that this data is for a Native American Tribe, and that the next field on the transaction identifies a tribal area using the Bureau of Indian Affairs tribal code.\r\n\r\nData in the application may be viewed in Tribal format by selecting Tribal Mode in the Admin > Security menu."},
#   {'field_name': 'county_code',
#    'field_description': "A Federal Information Processing Standards (FIPS) code that identifies a county, parish, or independent city within a state.  In certain cases other geo-political entities, such as tribe via the BIA tribal code, may be used.  For border sites, it identifies the geo-political equivalent to U. S. states, such as Mexican states or Canadian provinces.\r\n\r\nWhen submitting transactions, a user may opt to use a Bureau of Indian Affairs tribal code in this fied (if the State Code was entered as 'TT' to indicate that this data is for a Native American Tribe).\r\n\r\nData in the application may be viewed in Tribal format by selecting Tribal Mode in the Admin > Security menu.\r\n"},
#   {'field_name': 'site_number',
#    'field_description': 'The 4-digit number used to uniquely identify the air monitoring site within a county or tribal land.  The values are always numeric, but are treated as a string and padded with leading zeroes so they must always have 4 digits.\r\n\r\nThere is no requirement that Site Numbers be assigned continuously or in any particular order. Regional or local organizations are thus free to allocate Site Numbers in any way they choose, as long as there is no duplication within a county or tribal area.  Be aware that a tribal land using a Site Number will also reserve that Site Number for the overlapping county.  Likewise, if a county has already reserved a Site Number, it cannot be used for an overlapping Tribal land.\r\n\r\nIf a new Site Number is needed for a site that may lay in multiple jurisdictions, all agencies should cooperate to assign a Site Number to ensure that the Number is unique within the county and, for example, an ovelapping Tribal land. In other words, when a new Site Number is assigned, it must be different from any other Site Number already existing for that combination of State Code and County Code and Tribal land.\r\n\r\nA specific Site Number is associated with a specific physical location (latitide and longitude). Any change in location requires a new Site Number to be assigned (unless a waiver is obtained from the apporpriate regional office). Although a location change would routinely mean a new Site Number, some changes that do not change the site\'s location in respect to surrounding sources and its measurement scale may require no change. An EPA regional office should be consulted for assistance in determining whether a new site Number is required.  AQS also has the ability to "link" sites.  This allows the time series of data (used for NAAQS and other purposes) for a parameter to be considered continuous even if the site moved and the Site Number changed.\r\n\r\n\r\n'},
#   {'field_name': 'parameter_code',
#    'field_description': 'The AQS code corresponding to the parameter measured by the monitor.'},
#   {'field_name': 'poc',
#    'field_description': 'This is the "Parameter Occurrence Code" used to distinguish different instruments that measure the same parameter at the same site.  There is no meaning to the POC (e.g. POC 1 does not indicate the primary monitor).  For example, the first monitor established to measure carbon monoxide (CO) at a site could have a POC of 1. If an additional monitor were established at the same site to measure CO, that monitor could have a POC of 2. However, if a new instrument were installed to replace the original instrument used as the first monitor, that would be the same monitor and it would still have a POC of 1.\r\n\r\nFor criteria pollutants, data from different sampling methods should only be stored under the same POC if the sampling intervals are the same and the methods are reference or equivalent. For sites where duplicate sampling is being conducted by multiple agencies or by one agency with multiple samplers, multiple POCs must be utilized to store all samples.\r\n\r\nFor non-criteria pollutants, data from multiple sampling methods can be stored under the same POC if the sampling intervals are the same and there is only one sample for the time reported. If multiple open path monitors are reporting data for the same parameter, each open path would be assigned a different POC.\r\n\r\nWhile there are no national EPA practices assigning POC values, there may be regional or agency conventions where a POC value may have specific significance.  Since these do not apply universally, you will likely get the wrong set of monitors assuming the POC represents something.  There is enough metadata avaialable in AQS to correctly classify all monitors (e.g., primary, speciation, etc.)\r\n\r\nNumbers do not need to be assigned sequentially.'},
#   {'field_name': 'latitude',
#    'field_description': 'The angular distance north or south of the equator measured in decimal degrees.  North is positive.\r\n\r\nAQS converts reported coordinates (latitude and longitude) to the same datum so that sites can be more easily used for mapping and geospatial analysis.  The standard datum is WGS84 and this is the latitude in the WGS84 datum.'},
#   {'field_name': 'longitude',
#    'field_description': 'The angular distance east or west of the prime meridian measured in decimal degrees.  East is positive, West is negative.\r\n\r\nAQS converts reported coordinates (latitude and longitude) to the same datum so that sites can be more easily used for mapping and geospatial analysis.  The standard datum is WGS84 and this is the longitude in the WGS84 datum.'},
#   {'field_name': 'datum',
#    'field_description': 'The Datum associated with the Latitude and Longitude measures.  The Datum represents the physical model of the earth used when determining latitude and longitude.\r\n\r\nAQS computes a "standard" location representation for all site location/coordinates so that data from AQS can be more easily used for mapping and geospatial analysis. This is accomplished using a geodatabase lookup to convert the user-provided coordinates into Latitude and Longitude with the standard horizontal datum of WGS84. (i.e. This field will always be WGS84.)\r\n\r\nIf this field is blank, it means that either the user input coordinates or datum are unkown and unrecoverable.'},
#   {'field_name': 'parameter',
#    'field_description': 'The name or description assigned in AQS to the parameter measured by the monitor. Parameters may be pollutants or non-pollutants (e.g., wind speed).'},
#   {'field_name': 'date_local',
#    'field_description': 'The date the sample was taken in Local Standard Time.  This represents only the date, the time is in a separate field.  This time reflects the beginning of the sample duration.  That is, if the time is 2:00 and the duration is 1-hour, then sampling happened from 2:00 - 3:00.'},
#   {'field_name': 'time_local',
#    'field_description': 'The time of day that sampling began on a 24-hour clock in Local Standard Time.'},
#   {'field_name': 'date_gmt',
#    'field_description': 'The date the sample was taken in Greenwhich Mean Time.'},
#   {'field_name': 'time_gmt',
#    'field_description': 'The time of day that sampling began on a 24-hour clock in Greenwich Mean Time.'},
#   {'field_name': 'sample_measurement',
#    'field_description': 'The measured value in the standard units of measure for the parameter.\r\n\r\nThis value is calculated from the value reported to AQS using the following steps:\r\n\r\n* The units are converted from the reported units or measure to the AQS standard units of measure\r\n* The rounding and truncation rules for the parameter-method combination are applied.\r\n\r\nFor example:\r\n'},
#   {'field_name': 'units_of_measure',
#    'field_description': 'The unit of measure for all statistics on the same row.  Every parameter has a standard unit of measure.  Submitters are allowed to report data in any unit and EPA converts to a standard unit so that we may use the data in calculations.'},
#   {'field_name': 'sample_duration',
#    'field_description': 'The length of time that air passes through the monitoring device before it is analyzed (measured). So, it represents an averaging period in the atmosphere (for example, a 24-hour sample duration draws ambient air over a collection filter for 24 straight hours). For continuous monitors, it can represent an averaging time of many samples (for example, a 1-hour value may be the average of four one-minute samples collected during each quarter of the hour).\r\n\r\nThere are two types of sample durations.  First are "observed"; that is, this is the data reported to EPA as a sample measurement. 24-Hour is an observed duration and represents the average inherent in the monitoring method.\r\n\r\nThe others are "calculated" by AQS to match the form of the standard.  24-Hr-Block-Avg is a calculated duration.  This duration is needed to convert reported hourly data to the 24-hour averages needed to match the standard.'},
#   {'field_name': 'sample_frequency',
#    'field_description': 'The frequency at which sample observations are made.  Specified as the amount of time that elapses between the beginning of subsequent observations. Usually, this indicates how often 24-hour samples are taken, e.g., daily, every third day, stratified random, etc.  If this value is null, it implies continuous samples reported hourly.'},
#   {'field_name': 'detection_limit',
#    'field_description': 'The minimum sample concentration detectable for the monitor and method.  Each method has a federal MDL assigned to it by the EPA.  If the analyzing agency has determined and reported their own MDL, this will be listed rather than the federal MDL.'},
#   {'field_name': 'uncertainty',
#    'field_description': 'The total measurement uncertainty associated with a reported measurement as indicated by the reporting agency.  This includes method uncertainty, both the analytical and the volume uncertainty. No blank corrections are assumed (other than laboratory baseline corrections which are an integral part of each analysis).  Uncertainty should be reported in the same units of measure as the Sample Value.'},
#   {'field_name': 'qualifiers',
#    'field_description': 'Sample values may have qualifiers that indicate why they are missing or that they are out of the ordinary. Types of qualifiers are: null data, exceptional event, natural events, and quality assurance. All Qualifiers are described in this field.'},
#   {'field_name': 'method_type',
#    'field_description': 'An indication of whether the method used to collect the data is a federal reference method (FRM), equivalent to a federal reference method, an approved regional method, or none of the above (non-federal reference method).'},
#   {'field_name': 'method_code',
#    'field_description': 'A three-digit code representing the measurement method. A method code is only unique within a parameter (that is, method 132 for ozone is not the same as method 123 for benzene).  The encoding contains both the sample collection and sample analysis descriptions.'},
#   {'field_name': 'method',
#    'field_description': 'A short description of the processes, equipment, and protocols used in gathering and measuring the sample.  This field is a concatenation of the method of collection and the method of analysis.'},
#   {'field_name': 'state',
#    'field_description': 'The name of the state where the monitoring site is located.'},
#   {'field_name': 'county',
#    'field_description': 'The name of the county where the monitoring site is located.'},
#   {'field_name': 'date_of_last_change',
#    'field_description': 'This represents the date the most relevant underlying data in AQS was last changed.  That is, for annual summary data, it is the date these values were last affected by a change in raw data.  If the AQCR code on the annual summary view changed, the date of last change would not be updated.'},
#   {'field_name': 'cbsa_code',
#    'field_description': 'The code of the core based statistical area (metropolitan area) where the monitoring site is located.'}]}

# %%
# Extract the 'data' field and convert to a clean metadata dict
response_json = metadata.json()
metadata_dict = response_json.get("Data", [])

# Display the metadata
print(f"Found {len(metadata_dict)} metadata fields")
metadata_dict
# Out:
# Found 27 metadata fields
# [{'field_name': 'state_code',
#   'field_description': "The FIPS code of the state in which the monitor resides.  AQS uses 2-digit or character codes that identifies one of the 50 states, U. S. territories, or Washington, DC.  For border sites, the code '80' is used for Mexico and 'CC' is used for Canada.\r\n\r\nWhen submitting transactions, a user may opt to use the code 'TT' to indicate that this data is for a Native American Tribe, and that the next field on the transaction identifies a tribal area using the Bureau of Indian Affairs tribal code.\r\n\r\nData in the application may be viewed in Tribal format by selecting Tribal Mode in the Admin > Security menu."},
#  {'field_name': 'county_code',
#   'field_description': "A Federal Information Processing Standards (FIPS) code that identifies a county, parish, or independent city within a state.  In certain cases other geo-political entities, such as tribe via the BIA tribal code, may be used.  For border sites, it identifies the geo-political equivalent to U. S. states, such as Mexican states or Canadian provinces.\r\n\r\nWhen submitting transactions, a user may opt to use a Bureau of Indian Affairs tribal code in this fied (if the State Code was entered as 'TT' to indicate that this data is for a Native American Tribe).\r\n\r\nData in the application may be viewed in Tribal format by selecting Tribal Mode in the Admin > Security menu.\r\n"},
#  {'field_name': 'site_number',
#   'field_description': 'The 4-digit number used to uniquely identify the air monitoring site within a county or tribal land.  The values are always numeric, but are treated as a string and padded with leading zeroes so they must always have 4 digits.\r\n\r\nThere is no requirement that Site Numbers be assigned continuously or in any particular order. Regional or local organizations are thus free to allocate Site Numbers in any way they choose, as long as there is no duplication within a county or tribal area.  Be aware that a tribal land using a Site Number will also reserve that Site Number for the overlapping county.  Likewise, if a county has already reserved a Site Number, it cannot be used for an overlapping Tribal land.\r\n\r\nIf a new Site Number is needed for a site that may lay in multiple jurisdictions, all agencies should cooperate to assign a Site Number to ensure that the Number is unique within the county and, for example, an ovelapping Tribal land. In other words, when a new Site Number is assigned, it must be different from any other Site Number already existing for that combination of State Code and County Code and Tribal land.\r\n\r\nA specific Site Number is associated with a specific physical location (latitide and longitude). Any change in location requires a new Site Number to be assigned (unless a waiver is obtained from the apporpriate regional office). Although a location change would routinely mean a new Site Number, some changes that do not change the site\'s location in respect to surrounding sources and its measurement scale may require no change. An EPA regional office should be consulted for assistance in determining whether a new site Number is required.  AQS also has the ability to "link" sites.  This allows the time series of data (used for NAAQS and other purposes) for a parameter to be considered continuous even if the site moved and the Site Number changed.\r\n\r\n\r\n'},
#  {'field_name': 'parameter_code',
#   'field_description': 'The AQS code corresponding to the parameter measured by the monitor.'},
#  {'field_name': 'poc',
#   'field_description': 'This is the "Parameter Occurrence Code" used to distinguish different instruments that measure the same parameter at the same site.  There is no meaning to the POC (e.g. POC 1 does not indicate the primary monitor).  For example, the first monitor established to measure carbon monoxide (CO) at a site could have a POC of 1. If an additional monitor were established at the same site to measure CO, that monitor could have a POC of 2. However, if a new instrument were installed to replace the original instrument used as the first monitor, that would be the same monitor and it would still have a POC of 1.\r\n\r\nFor criteria pollutants, data from different sampling methods should only be stored under the same POC if the sampling intervals are the same and the methods are reference or equivalent. For sites where duplicate sampling is being conducted by multiple agencies or by one agency with multiple samplers, multiple POCs must be utilized to store all samples.\r\n\r\nFor non-criteria pollutants, data from multiple sampling methods can be stored under the same POC if the sampling intervals are the same and there is only one sample for the time reported. If multiple open path monitors are reporting data for the same parameter, each open path would be assigned a different POC.\r\n\r\nWhile there are no national EPA practices assigning POC values, there may be regional or agency conventions where a POC value may have specific significance.  Since these do not apply universally, you will likely get the wrong set of monitors assuming the POC represents something.  There is enough metadata avaialable in AQS to correctly classify all monitors (e.g., primary, speciation, etc.)\r\n\r\nNumbers do not need to be assigned sequentially.'},
#  {'field_name': 'latitude',
#   'field_description': 'The angular distance north or south of the equator measured in decimal degrees.  North is positive.\r\n\r\nAQS converts reported coordinates (latitude and longitude) to the same datum so that sites can be more easily used for mapping and geospatial analysis.  The standard datum is WGS84 and this is the latitude in the WGS84 datum.'},
#  {'field_name': 'longitude',
#   'field_description': 'The angular distance east or west of the prime meridian measured in decimal degrees.  East is positive, West is negative.\r\n\r\nAQS converts reported coordinates (latitude and longitude) to the same datum so that sites can be more easily used for mapping and geospatial analysis.  The standard datum is WGS84 and this is the longitude in the WGS84 datum.'},
#  {'field_name': 'datum',
#   'field_description': 'The Datum associated with the Latitude and Longitude measures.  The Datum represents the physical model of the earth used when determining latitude and longitude.\r\n\r\nAQS computes a "standard" location representation for all site location/coordinates so that data from AQS can be more easily used for mapping and geospatial analysis. This is accomplished using a geodatabase lookup to convert the user-provided coordinates into Latitude and Longitude with the standard horizontal datum of WGS84. (i.e. This field will always be WGS84.)\r\n\r\nIf this field is blank, it means that either the user input coordinates or datum are unkown and unrecoverable.'},
#  {'field_name': 'parameter',
#   'field_description': 'The name or description assigned in AQS to the parameter measured by the monitor. Parameters may be pollutants or non-pollutants (e.g., wind speed).'},
#  {'field_name': 'date_local',
#   'field_description': 'The date the sample was taken in Local Standard Time.  This represents only the date, the time is in a separate field.  This time reflects the beginning of the sample duration.  That is, if the time is 2:00 and the duration is 1-hour, then sampling happened from 2:00 - 3:00.'},
#  {'field_name': 'time_local',
#   'field_description': 'The time of day that sampling began on a 24-hour clock in Local Standard Time.'},
#  {'field_name': 'date_gmt',
#   'field_description': 'The date the sample was taken in Greenwhich Mean Time.'},
#  {'field_name': 'time_gmt',
#   'field_description': 'The time of day that sampling began on a 24-hour clock in Greenwich Mean Time.'},
#  {'field_name': 'sample_measurement',
#   'field_description': 'The measured value in the standard units of measure for the parameter.\r\n\r\nThis value is calculated from the value reported to AQS using the following steps:\r\n\r\n* The units are converted from the reported units or measure to the AQS standard units of measure\r\n* The rounding and truncation rules for the parameter-method combination are applied.\r\n\r\nFor example:\r\n'},
#  {'field_name': 'units_of_measure',
#   'field_description': 'The unit of measure for all statistics on the same row.  Every parameter has a standard unit of measure.  Submitters are allowed to report data in any unit and EPA converts to a standard unit so that we may use the data in calculations.'},
#  {'field_name': 'sample_duration',
#   'field_description': 'The length of time that air passes through the monitoring device before it is analyzed (measured). So, it represents an averaging period in the atmosphere (for example, a 24-hour sample duration draws ambient air over a collection filter for 24 straight hours). For continuous monitors, it can represent an averaging time of many samples (for example, a 1-hour value may be the average of four one-minute samples collected during each quarter of the hour).\r\n\r\nThere are two types of sample durations.  First are "observed"; that is, this is the data reported to EPA as a sample measurement. 24-Hour is an observed duration and represents the average inherent in the monitoring method.\r\n\r\nThe others are "calculated" by AQS to match the form of the standard.  24-Hr-Block-Avg is a calculated duration.  This duration is needed to convert reported hourly data to the 24-hour averages needed to match the standard.'},
#  {'field_name': 'sample_frequency',
#   'field_description': 'The frequency at which sample observations are made.  Specified as the amount of time that elapses between the beginning of subsequent observations. Usually, this indicates how often 24-hour samples are taken, e.g., daily, every third day, stratified random, etc.  If this value is null, it implies continuous samples reported hourly.'},
#  {'field_name': 'detection_limit',
#   'field_description': 'The minimum sample concentration detectable for the monitor and method.  Each method has a federal MDL assigned to it by the EPA.  If the analyzing agency has determined and reported their own MDL, this will be listed rather than the federal MDL.'},
#  {'field_name': 'uncertainty',
#   'field_description': 'The total measurement uncertainty associated with a reported measurement as indicated by the reporting agency.  This includes method uncertainty, both the analytical and the volume uncertainty. No blank corrections are assumed (other than laboratory baseline corrections which are an integral part of each analysis).  Uncertainty should be reported in the same units of measure as the Sample Value.'},
#  {'field_name': 'qualifiers',
#   'field_description': 'Sample values may have qualifiers that indicate why they are missing or that they are out of the ordinary. Types of qualifiers are: null data, exceptional event, natural events, and quality assurance. All Qualifiers are described in this field.'},
#  {'field_name': 'method_type',
#   'field_description': 'An indication of whether the method used to collect the data is a federal reference method (FRM), equivalent to a federal reference method, an approved regional method, or none of the above (non-federal reference method).'},
#  {'field_name': 'method_code',
#   'field_description': 'A three-digit code representing the measurement method. A method code is only unique within a parameter (that is, method 132 for ozone is not the same as method 123 for benzene).  The encoding contains both the sample collection and sample analysis descriptions.'},
#  {'field_name': 'method',
#   'field_description': 'A short description of the processes, equipment, and protocols used in gathering and measuring the sample.  This field is a concatenation of the method of collection and the method of analysis.'},
#  {'field_name': 'state',
#   'field_description': 'The name of the state where the monitoring site is located.'},
#  {'field_name': 'county',
#   'field_description': 'The name of the county where the monitoring site is located.'},
#  {'field_name': 'date_of_last_change',
#   'field_description': 'This represents the date the most relevant underlying data in AQS was last changed.  That is, for annual summary data, it is the date these values were last affected by a change in raw data.  If the AQCR code on the annual summary view changed, the date of last change would not be updated.'},
#  {'field_name': 'cbsa_code',
#   'field_description': 'The code of the core based statistical area (metropolitan area) where the monitoring site is located.'}]

# %%
# Write metadata to a nicely formatted markdown file
with open("metadata.md", "w", encoding="utf-8") as f:
    f.write("# API Metadata Fields\n\n")
    f.write(f"**Service:** sampleData\n\n")
    f.write(f"**Total Fields:** {len(metadata_dict)}\n\n")
    f.write("---\n\n")
    
    for i, field in enumerate(metadata_dict, 1):
        f.write(f"## {i}. {field.get('field_name', 'N/A')}\n\n")
        f.write(f"{field.get('field_description', 'N/A')}")
        f.write("\n")

print("Metadata written to metadata.md")
# Out:
# Metadata written to metadata.md

# %%
params = {
    "email": "vogt.benjamin.a@gmail.com",
    "key": api_key,
}
states = requests.get("https://aqs.epa.gov/data/api/list/states", params=params)

# %%
states_json = states.json()
states_json
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2025-11-13T06:15:19-05:00',
#    'url': 'https://aqs.epa.gov/data/api/list/states?email=vogt.benjamin.a%40gmail.com&key=greenmouse47',
#    'rows': 56}],
#  'Data': [{'code': '01', 'value_represented': 'Alabama'},
#   {'code': '02', 'value_represented': 'Alaska'},
#   {'code': '04', 'value_represented': 'Arizona'},
#   {'code': '05', 'value_represented': 'Arkansas'},
#   {'code': '06', 'value_represented': 'California'},
#   {'code': '08', 'value_represented': 'Colorado'},
#   {'code': '09', 'value_represented': 'Connecticut'},
#   {'code': '10', 'value_represented': 'Delaware'},
#   {'code': '11', 'value_represented': 'District Of Columbia'},
#   {'code': '12', 'value_represented': 'Florida'},
#   {'code': '13', 'value_represented': 'Georgia'},
#   {'code': '15', 'value_represented': 'Hawaii'},
#   {'code': '16', 'value_represented': 'Idaho'},
#   {'code': '17', 'value_represented': 'Illinois'},
#   {'code': '18', 'value_represented': 'Indiana'},
#   {'code': '19', 'value_represented': 'Iowa'},
#   {'code': '20', 'value_represented': 'Kansas'},
#   {'code': '21', 'value_represented': 'Kentucky'},
#   {'code': '22', 'value_represented': 'Louisiana'},
#   {'code': '23', 'value_represented': 'Maine'},
#   {'code': '24', 'value_represented': 'Maryland'},
#   {'code': '25', 'value_represented': 'Massachusetts'},
#   {'code': '26', 'value_represented': 'Michigan'},
#   {'code': '27', 'value_represented': 'Minnesota'},
#   {'code': '28', 'value_represented': 'Mississippi'},
#   {'code': '29', 'value_represented': 'Missouri'},
#   {'code': '30', 'value_represented': 'Montana'},
#   {'code': '31', 'value_represented': 'Nebraska'},
#   {'code': '32', 'value_represented': 'Nevada'},
#   {'code': '33', 'value_represented': 'New Hampshire'},
#   {'code': '34', 'value_represented': 'New Jersey'},
#   {'code': '35', 'value_represented': 'New Mexico'},
#   {'code': '36', 'value_represented': 'New York'},
#   {'code': '37', 'value_represented': 'North Carolina'},
#   {'code': '38', 'value_represented': 'North Dakota'},
#   {'code': '39', 'value_represented': 'Ohio'},
#   {'code': '40', 'value_represented': 'Oklahoma'},
#   {'code': '41', 'value_represented': 'Oregon'},
#   {'code': '42', 'value_represented': 'Pennsylvania'},
#   {'code': '44', 'value_represented': 'Rhode Island'},
#   {'code': '45', 'value_represented': 'South Carolina'},
#   {'code': '46', 'value_represented': 'South Dakota'},
#   {'code': '47', 'value_represented': 'Tennessee'},
#   {'code': '48', 'value_represented': 'Texas'},
#   {'code': '49', 'value_represented': 'Utah'},
#   {'code': '50', 'value_represented': 'Vermont'},
#   {'code': '51', 'value_represented': 'Virginia'},
#   {'code': '53', 'value_represented': 'Washington'},
#   {'code': '54', 'value_represented': 'West Virginia'},
#   {'code': '55', 'value_represented': 'Wisconsin'},
#   {'code': '56', 'value_represented': 'Wyoming'},
#   {'code': '66', 'value_represented': 'Guam'},
#   {'code': '72', 'value_represented': 'Puerto Rico'},
#   {'code': '78', 'value_represented': 'Virgin Islands'},
#   {'code': '80', 'value_represented': 'Country Of Mexico'},
#   {'code': 'CC', 'value_represented': 'Canada'}]}

# %%
# Create a dictionary mapping state names to their codes used by the API

state_codes = {}
for state in states.json().get('Data'):
    state_codes[state.get('value_represented')] = state.get('code')

state_codes
# Out:
# {'Alabama': '01',
#  'Alaska': '02',
#  'Arizona': '04',
#  'Arkansas': '05',
#  'California': '06',
#  'Colorado': '08',
#  'Connecticut': '09',
#  'Delaware': '10',
#  'District Of Columbia': '11',
#  'Florida': '12',
#  'Georgia': '13',
#  'Hawaii': '15',
#  'Idaho': '16',
#  'Illinois': '17',
#  'Indiana': '18',
#  'Iowa': '19',
#  'Kansas': '20',
#  'Kentucky': '21',
#  'Louisiana': '22',
#  'Maine': '23',
#  'Maryland': '24',
#  'Massachusetts': '25',
#  'Michigan': '26',
#  'Minnesota': '27',
#  'Mississippi': '28',
#  'Missouri': '29',
#  'Montana': '30',
#  'Nebraska': '31',
#  'Nevada': '32',
#  'New Hampshire': '33',
#  'New Jersey': '34',
#  'New Mexico': '35',
#  'New York': '36',
#  'North Carolina': '37',
#  'North Dakota': '38',
#  'Ohio': '39',
#  'Oklahoma': '40',
#  'Oregon': '41',
#  'Pennsylvania': '42',
#  'Rhode Island': '44',
#  'South Carolina': '45',
#  'South Dakota': '46',
#  'Tennessee': '47',
#  'Texas': '48',
#  'Utah': '49',
#  'Vermont': '50',
#  'Virginia': '51',
#  'Washington': '53',
#  'West Virginia': '54',
#  'Wisconsin': '55',
#  'Wyoming': '56',
#  'Guam': '66',
#  'Puerto Rico': '72',
#  'Virgin Islands': '78',
#  'Country Of Mexico': '80',
#  'Canada': 'CC'}

# %%
# Retrieve a list of parameter classes used by the API

classes = requests.get("https://aqs.epa.gov/data/api/list/classes", params=params)
classes_json = classes.json()
classes_json
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2025-11-13T06:22:12-05:00',
#    'url': 'https://aqs.epa.gov/data/api/list/classes?email=vogt.benjamin.a%40gmail.com&key=greenmouse47',
#    'rows': 27}],
#  'Data': [{'code': 'AIRNOW MAPS',
#    'value_represented': 'The parameters represented on AirNow maps (88101, 88502, and 44201)'},
#   {'code': 'ALL', 'value_represented': 'Select all Parameters Available'},
#   {'code': 'AQI POLLUTANTS',
#    'value_represented': 'Pollutants that have an AQI Defined'},
#   {'code': 'CORE_HAPS', 'value_represented': 'Urban Air Toxic Pollutants'},
#   {'code': 'CRITERIA', 'value_represented': 'Criteria Pollutants'},
#   {'code': 'CSN DART',
#    'value_represented': 'List of CSN speciation parameters to populate the STI DART tool'},
#   {'code': 'FORECAST',
#    'value_represented': 'Parameters routinely extracted by AirNow (STI)'},
#   {'code': 'HAPS', 'value_represented': 'Hazardous Air Pollutants'},
#   {'code': 'IMPROVE CARBON', 'value_represented': 'IMPROVE Carbon Parameters'},
#   {'code': 'IMPROVE_SPECIATION',
#    'value_represented': 'PM2.5 Speciated Parameters Measured at IMPROVE sites'},
#   {'code': 'MET', 'value_represented': 'Meteorological Parameters'},
#   {'code': 'NATTS CORE HAPS',
#    'value_represented': 'The core list of toxics of interest to the NATTS program.'},
#   {'code': 'NATTS REQUIRED',
#    'value_represented': 'Required compounds to be collected in the National Air Toxics Network'},
#   {'code': 'PAMS',
#    'value_represented': 'Photochemical Assessment Monitoring System'},
#   {'code': 'PAMS_VOC',
#    'value_represented': 'Volatile Organic Compound subset of the PAMS Parameters'},
#   {'code': 'PM COARSE',
#    'value_represented': 'PM between 2.5 and 10 micrometers'},
#   {'code': 'PM10 SPECIATION',
#    'value_represented': 'PM10 Speciated Parameters'},
#   {'code': 'PM2.5 CONT NONREF',
#    'value_represented': 'PM2.5 Continuous, Nonreference Methods'},
#   {'code': 'PM2.5 MASS/QA',
#    'value_represented': 'PM2.5 Mass and QA Parameters'},
#   {'code': 'SCHOOL AIR TOXICS',
#    'value_represented': 'School Air Toxics Program Parameters'},
#   {'code': 'SPECIATION', 'value_represented': 'PM2.5 Speciated Parameters'},
#   {'code': 'SPECIATION CARBON',
#    'value_represented': 'PM2.5 Speciation Carbon Parameters'},
#   {'code': 'SPECIATION CATION/ANION',
#    'value_represented': 'PM2.5 Speciation Cation/Anion Parameters'},
#   {'code': 'SPECIATION METALS',
#    'value_represented': 'PM2.5 Speciation Metal Parameters'},
#   {'code': 'UATMP CARBONYL',
#    'value_represented': 'Urban Air Toxics Monitoring Program Carbonyls'},
#   {'code': 'UATMP VOC',
#    'value_represented': 'Urban Air Toxics Monitoring Program VOCs'},
#   {'code': 'VOC', 'value_represented': 'Volatile organic compounds'}]}

# %%
# Write parameters to a nicely formatted markdown file
classes_data = classes_json.get("Data", [])

params = {
    "email": "vogt.benjamin.a@gmail.com",
    "key": api_key,
}

with open("codes.md", "w", encoding="utf-8") as f:
    f.write("# API Parameter Classes\n\n")
    f.write(f"**Total Fields:** {len(classes_data)}\n\n")
    f.write("---\n\n")
    
    for i, field in enumerate(classes_data, 1):
        f.write(f"## {i}. {field.get('code', 'N/A')}\n\n")
        f.write(f"{field.get('value_represented', 'N/A')}\n\n")
        params["pc"] = field.get('code', 'N/A')
        codes = requests.get("https://aqs.epa.gov/data/api/list/parametersByClass", params=params)
        time.sleep(6)  # They said no more than 10 requests per minute
        codes_data = codes.json().get("Data", [])
        for j, code in enumerate(codes_data, 1):
            f.write(f"- Code:{code.get('code', 'N/A')} (Value Represented: {code.get('value_represented', 'N/A')})\n")

        f.write("\n")

print("Classes & codes written to codes.md")
# Out:
# Classes & codes written to codes.md

# %%
params["pc"] = "CRITERIA"
codes = requests.get("https://aqs.epa.gov/data/api/list/parametersByClass", params=params)

# %%
codes.json()
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2025-11-13T07:48:35-05:00',
#    'url': 'https://aqs.epa.gov/data/api/list/parametersByClass?email=vogt.benjamin.a%40gmail.com&key=greenmouse47&pc=CRITERIA',
#    'rows': 8}],
#  'Data': [{'code': '14129', 'value_represented': 'Lead (TSP) LC'},
#   {'code': '42101', 'value_represented': 'Carbon monoxide'},
#   {'code': '42401', 'value_represented': 'Sulfur dioxide'},
#   {'code': '42602', 'value_represented': 'Nitrogen dioxide (NO2)'},
#   {'code': '44201', 'value_represented': 'Ozone'},
#   {'code': '81102', 'value_represented': 'PM10 Total 0-10um STP'},
#   {'code': '85129', 'value_represented': 'Lead PM10 LC FRM/FEM'},
#   {'code': '88101', 'value_represented': 'PM2.5 - Local Conditions'}]}

# %%
criteria_codes = {}
criteria = ["PM2.5 - Local Conditions", "Ozone", "Nitrogen dioxide (NO2)", "Sulfur dioxide", "Carbon monoxide"]
code_data = codes.json().get("Data", [])
for code in code_data:
    if code.get("value_represented") in criteria:
        criteria_codes[code.get("value_represented")] = code.get("code")
criteria_codes
# Out:
# {'Carbon monoxide': '42101',
#  'Sulfur dioxide': '42401',
#  'Nitrogen dioxide (NO2)': '42602',
#  'Ozone': '44201',
#  'PM2.5 - Local Conditions': '88101'}

# %%
criteria_codes["PM2.5"] = criteria_codes.pop("PM2.5 - Local Conditions")
criteria_codes
# Out:
# {'Carbon monoxide': '42101',
#  'Sulfur dioxide': '42401',
#  'Nitrogen dioxide (NO2)': '42602',
#  'Ozone': '44201',
#  'PM2.5': '88101'}

# %%
# Retrieve sample data for the selected criteria pollutants in Illinois for January 2020

params = {
    "email": "vogt.benjamin.a@gmail.com",
    "key": api_key,
    "param": ",".join(criteria_codes.values()),
    "bdate": "20200101",
    "edate": "20200131",
    "state": state_codes["Illinois"],
}

samples = requests.get("https://aqs.epa.gov/data/api/sampleData/byState", params=params)
samples_data = samples.json()
# Save to file
with open("samples_data.json", "w", encoding="utf-8") as f:
    json.dump(samples_data, f, indent=2) # Pretty print with indent=2: may remove later to save file size

print("Data saved to samples_data.json")
# Out:
# Data saved to samples_data.json

# %%
with open("samples_data.json", "r") as f:
    samples_data = json.load(f)

# Extract only the Data array
df = pd.DataFrame(samples_data["Data"])

# %%
df.head()
# Out:
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         17         119        3007          88101    1  38.860669
# 1         17         119        3007          88101    1  38.860669
# 2         17         119        3007          88101    1  38.860669
# 3         17         119        3007          88101    1  38.860669
# 4         17         119        3007          88101    1  38.860669
#
#    longitude  datum                 parameter  date_local  ...  \
# 0 -90.105851  WGS84  PM2.5 - Local Conditions  2020-01-01  ...
# 1 -90.105851  WGS84  PM2.5 - Local Conditions  2020-01-04  ...
# 2 -90.105851  WGS84  PM2.5 - Local Conditions  2020-01-07  ...
# 3 -90.105851  WGS84  PM2.5 - Local Conditions  2020-01-10  ...
# 4 -90.105851  WGS84  PM2.5 - Local Conditions  2020-01-13  ...
#
#   detection_limit uncertainty qualifier  method_type  \
# 0             2.0        None      None          FRM
# 1             2.0        None      None          FRM
# 2             2.0        None      None          FRM
# 3             2.0        None      None          FRM
# 4             2.0        None      None          FRM
#
#                                               method method_code     state  \
# 0  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...         143  Illinois
# 1  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...         143  Illinois
# 2  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...         143  Illinois
# 3  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...         143  Illinois
# 4  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...         143  Illinois
#
#     county date_of_last_change  cbsa_code
# 0  Madison          2020-03-11      41180
# 1  Madison          2020-03-11      41180
# 2  Madison          2020-03-11      41180
# 3  Madison          2020-03-11      41180
# 4  Madison          2020-03-11      41180
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['state_code', 'county_code', 'site_number', 'parameter_code', 'poc',
#        'latitude', 'longitude', 'datum', 'parameter', 'date_local',
#        'time_local', 'date_gmt', 'time_gmt', 'sample_measurement',
#        'units_of_measure', 'units_of_measure_code', 'sample_duration',
#        'sample_duration_code', 'sample_frequency', 'detection_limit',
#        'uncertainty', 'qualifier', 'method_type', 'method', 'method_code',
#        'state', 'county', 'date_of_last_change', 'cbsa_code'],
#       dtype='object')

# %%
df["sample_measurement"].value_counts()
# Out:
# sample_measurement
# 0.300     2438
# 0.400     2417
# 0.500     1731
# 0.000     1670
# 0.200     1536
#           ...
# 0.461        1
# 0.465        1
# 0.553        1
# 0.481        1
# 34.400       1
# Name: count, Length: 865, dtype: int64

# %%
df[df["sample_measurement"] < df["detection_limit"]][["sample_measurement", "detection_limit"]]
# Out:
#        sample_measurement  detection_limit
# 167                 -15.9              2.0
# 168                 -13.4              2.0
# 169                 -14.0              2.0
# 170                 -21.4              2.0
# 171                 -16.1              2.0
# ...                   ...              ...
# 52219                 2.3              2.7
# 52646                 0.3              0.4
# 52647                 0.3              0.4
# 52660                 0.3              0.4
# 52668                 0.3              0.4
#
# [8299 rows x 2 columns]

# %%
df[df["sample_measurement"].isna()]
# Out:
#       state_code county_code site_number parameter_code  poc   latitude  \
# 43            17         019        0006          88101    1  40.123886
# 44            17         089        0007          88101    1  41.784717
# 50            17         031        3301          88101    9  41.782766
# 51            17         031        3301          88101    9  41.782766
# 64            17         119        1007          88101    9  38.704534
# ...          ...         ...         ...            ...  ...        ...
# 52278         17         117        0002          42602    1  39.396075
# 52279         17         117        0002          42602    1  39.396075
# 52280         17         117        0002          42602    1  39.396075
# 52281         17         117        0002          42602    1  39.396075
# 52282         17         117        0002          42602    1  39.396075
#
#        longitude  datum                 parameter  date_local  ...  \
# 43    -88.240553  WGS84  PM2.5 - Local Conditions  2020-01-31  ...
# 44    -88.329374  WGS84  PM2.5 - Local Conditions  2020-01-25  ...
# 50    -87.805377  WGS84  PM2.5 - Local Conditions  2020-01-16  ...
# 51    -87.805377  WGS84  PM2.5 - Local Conditions  2020-01-28  ...
# 64    -90.139675  WGS84  PM2.5 - Local Conditions  2020-01-28  ...
# ...          ...    ...                       ...         ...  ...
# 52278 -89.809739  WGS84    Nitrogen dioxide (NO2)  2020-01-22  ...
# 52279 -89.809739  WGS84    Nitrogen dioxide (NO2)  2020-01-24  ...
# 52280 -89.809739  WGS84    Nitrogen dioxide (NO2)  2020-01-26  ...
# 52281 -89.809739  WGS84    Nitrogen dioxide (NO2)  2020-01-28  ...
# 52282 -89.809739  WGS84    Nitrogen dioxide (NO2)  2020-01-30  ...
#
#       detection_limit uncertainty                                   qualifier  \
# 43                2.0        None                   AN - Machine Malfunction.
# 44                2.0        None  AH - Sample Flow Rate or CV out of Limits.
# 50                2.0        None   BR - Sample Value Below Acceptable Range.
# 51                2.0        None        AS - Poor Quality Assurance Results.
# 64                2.0        None        AS - Poor Quality Assurance Results.
# ...               ...         ...                                         ...
# 52278             2.7        None        AY - Q C Control Points (zero/span).
# 52279             2.7        None        AY - Q C Control Points (zero/span).
# 52280             2.7        None        AY - Q C Control Points (zero/span).
# 52281             2.7        None        AY - Q C Control Points (zero/span).
# 52282             2.7        None        AY - Q C Control Points (zero/span).
#
#        method_type                                             method  \
# 43             FRM  BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 44             FRM  Thermo Electron Model RAAS2.5-100 w/VSCC - Gra...
# 50             FRM    Met One E-SEQ-FRM PM2.5 with VSCC - Gravimetric
# 51             FRM    Met One E-SEQ-FRM PM2.5 with VSCC - Gravimetric
# 64             FRM  BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# ...            ...                                                ...
# 52278          FRM         INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 52279          FRM         INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 52280          FRM         INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 52281          FRM         INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 52282          FRM         INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
#
#       method_code     state     county date_of_last_change  cbsa_code
# 43            142  Illinois  Champaign          2020-03-11      16580
# 44            153  Illinois       Kane          2020-03-11      16980
# 50            545  Illinois       Cook          2020-03-11      16980
# 51            545  Illinois       Cook          2020-03-11      16980
# 64            142  Illinois    Madison          2020-03-11      41180
# ...           ...       ...        ...                 ...        ...
# 52278         099  Illinois   Macoupin          2020-03-27      41180
# 52279         099  Illinois   Macoupin          2020-03-27      41180
# 52280         099  Illinois   Macoupin          2020-03-27      41180
# 52281         099  Illinois   Macoupin          2020-03-27      41180
# 52282         099  Illinois   Macoupin          2020-03-27      41180
#
# [12634 rows x 29 columns]

# %%
df.isna().sum()
# Out:
# state_code                   0
# county_code                  0
# site_number                  0
# parameter_code               0
# poc                          0
# latitude                     0
# longitude                    0
# datum                        0
# parameter                    0
# date_local                   0
# time_local                   0
# date_gmt                     0
# time_gmt                     0
# sample_measurement       12634
# units_of_measure             0
# units_of_measure_code        0
# sample_duration              0
# sample_duration_code         0
# sample_frequency         17848
# detection_limit              0
# uncertainty              53027
# qualifier                40370
# method_type                  0
# method                       0
# method_code                  0
# state                        0
# county                       0
# date_of_last_change          0
# cbsa_code                 2976
# dtype: int64

# %%
len(df) - 40370
# Out:
# 12657

# %%
df.dropna(subset=["sample_measurement"], inplace=True) # If sample_measurement is NaN, the row is useless

# %%
df.isna().sum()
# Out:
# state_code                   0
# county_code                  0
# site_number                  0
# parameter_code               0
# poc                          0
# latitude                     0
# longitude                    0
# datum                        0
# parameter                    0
# date_local                   0
# time_local                   0
# date_gmt                     0
# time_gmt                     0
# sample_measurement           0
# units_of_measure             0
# units_of_measure_code        0
# sample_duration              0
# sample_duration_code         0
# sample_frequency          7430
# detection_limit              0
# uncertainty              40393
# qualifier                40370
# method_type                  0
# method                       0
# method_code                  0
# state                        0
# county                       0
# date_of_last_change          0
# cbsa_code                 2881
# dtype: int64

# %%
df["qualifier"].value_counts()
# Out:
# qualifier
# V - Validated Value.    23
# Name: count, dtype: int64

# %%
df[df["sample_measurement"] < 0][["qualifier", "sample_measurement", "detection_limit"]]
# Out:
#                   qualifier  sample_measurement  detection_limit
# 167    V - Validated Value.               -15.9              2.0
# 168    V - Validated Value.               -13.4              2.0
# 169    V - Validated Value.               -14.0              2.0
# 170    V - Validated Value.               -21.4              2.0
# 171    V - Validated Value.               -16.1              2.0
# ...                     ...                 ...              ...
# 47235                  None                -0.1              0.2
# 47238                  None                -0.1              0.2
# 47319                  None                -0.1              0.2
# 48296                  None                -0.1              0.2
# 50586                  None                -0.1              0.2
#
# [1174 rows x 3 columns]

# %%
# Replace measurements below detection limit with 1/2 of detection limit: they are valid measurements but too small to be guaranteed to be accurate.
mask = df["sample_measurement"] < df["detection_limit"]
df.loc[mask, "sample_measurement"] = df.loc[mask, "detection_limit"] / 2

print(f"Replaced {mask.sum()} measurements below detection limit with 1/2 detection limit")
# Out:
# Replaced 8299 measurements below detection limit with 1/2 detection limit

# %%
df[df["sample_measurement"] < 0][["qualifier", "sample_measurement", "detection_limit"]]
# Out:
# Empty DataFrame
# Columns: [qualifier, sample_measurement, detection_limit]
# Index: []

# %%
# Remove the highest 0.01% outliers for each parameter
outliers = df.groupby("parameter", group_keys=False).apply(lambda x: x[x["sample_measurement"] >= x["sample_measurement"].quantile(0.9999)], include_groups=False) # Todo: Devise more sophisticated method for detecting outlier points
df = df[~df.index.isin(outliers.index)]

print(f"Removed {len(outliers)} outlier points. Remaining: {len(df)} rows")
# Out:
# Removed 8 outlier points. Remaining: 40385 rows
# C:\Users\Ben\AppData\Local\Temp\ipykernel_8264\3257392485.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   outliers = df.groupby("parameter").apply(lambda x: x[x["sample_measurement"] >= x["sample_measurement"].quantile(0.9999)]) # Todo: Devise more sophisticated method for detecting outlier points

# %%
outliers
# Out:
#                                state_code county_code site_number  \
# parameter
# Carbon monoxide          19147         17         031        0119
# Nitrogen dioxide (NO2)   38091         17         031        0119
# Ozone                    1034          17         031        4201
#                          1059          17         031        4201
# PM2.5 - Local Conditions 4455          17         115        0013
#                          25455         17         157        0001
# Sulfur dioxide           16842         17         115        0317
#                          28358         17         115        0217
#
#                                parameter_code  poc   latitude  longitude  \
# parameter
# Carbon monoxide          19147          42101    1  41.578620 -87.557406
# Nitrogen dioxide (NO2)   38091          42602    1  41.578620 -87.557406
# Ozone                    1034           44201    1  42.139996 -87.799227
#                          1059           44201    1  42.139996 -87.799227
# PM2.5 - Local Conditions 4455           88101    3  39.866834 -88.925594
#                          25455          88101    3  38.176278 -89.788459
# Sulfur dioxide           16842          42401    1  39.846856 -88.923323
#                          28358          42401    1  39.850712 -88.933635
#
#                                 datum                 parameter  date_local  \
# parameter
# Carbon monoxide          19147  NAD83           Carbon monoxide  2020-01-21
# Nitrogen dioxide (NO2)   38091  NAD83    Nitrogen dioxide (NO2)  2020-01-21
# Ozone                    1034   WGS84                     Ozone  2020-01-20
#                          1059   WGS84                     Ozone  2020-01-21
# PM2.5 - Local Conditions 4455   WGS84  PM2.5 - Local Conditions  2020-01-21
#                          25455  WGS84  PM2.5 - Local Conditions  2020-01-15
# Sulfur dioxide           16842  NAD83            Sulfur dioxide  2020-01-06
#                          28358  NAD83            Sulfur dioxide  2020-01-17
#
#                                 ... detection_limit uncertainty qualifier  \
# parameter                       ...
# Carbon monoxide          19147  ...           0.500        None      None
# Nitrogen dioxide (NO2)   38091  ...           0.040        None      None
# Ozone                    1034   ...           0.005        None      None
#                          1059   ...           0.005        None      None
# PM2.5 - Local Conditions 4455   ...           2.000        None      None
#                          25455  ...           2.000        None      None
# Sulfur dioxide           16842  ...           2.000        None      None
#                          28358  ...           2.000        None      None
#
#                                 method_type  \
# parameter
# Carbon monoxide          19147          FRM
# Nitrogen dioxide (NO2)   38091          FEM
# Ozone                    1034           FEM
#                          1059           FEM
# PM2.5 - Local Conditions 4455           FEM
#                          25455          FEM
# Sulfur dioxide           16842          FEM
#                          28358          FEM
#
#                                                                            method  \
# parameter
# Carbon monoxide          19147  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER
# Nitrogen dioxide (NO2)   38091  Teledyne Model T500U - Cavity Attenuated Phase...
# Ozone                    1034                         INSTRUMENTAL - ULTRA VIOLET
#                          1059                         INSTRUMENTAL - ULTRA VIOLET
# PM2.5 - Local Conditions 4455   Thermo Scientific 5014i or FH62C14-DHS w/VSCC ...
#                          25455  Thermo Scientific 5014i or FH62C14-DHS w/VSCC ...
# Sulfur dioxide           16842                  INSTRUMENTAL - PULSED FLUORESCENT
#                          28358                  INSTRUMENTAL - PULSED FLUORESCENT
#
#                                method_code     state    county  \
# parameter
# Carbon monoxide          19147         093  Illinois      Cook
# Nitrogen dioxide (NO2)   38091         212  Illinois      Cook
# Ozone                    1034          047  Illinois      Cook
#                          1059          047  Illinois      Cook
# PM2.5 - Local Conditions 4455          183  Illinois     Macon
#                          25455         183  Illinois  Randolph
# Sulfur dioxide           16842         060  Illinois     Macon
#                          28358         060  Illinois     Macon
#
#                                date_of_last_change  cbsa_code
# parameter
# Carbon monoxide          19147          2020-03-27      16980
# Nitrogen dioxide (NO2)   38091          2020-03-27      16980
# Ozone                    1034           2020-03-27      16980
#                          1059           2020-03-27      16980
# PM2.5 - Local Conditions 4455           2020-03-27      19500
#                          25455          2020-03-27       None
# Sulfur dioxide           16842          2020-05-27      19500
#                          28358          2020-05-27      19500
#
# [8 rows x 29 columns]

# %%
df[["date_gmt", "time_gmt","poc", "state_code", "county_code", "site_number", "parameter"]].value_counts()
# Out:
# date_gmt    time_gmt  poc  state_code  county_code  site_number  parameter
# 2020-01-01  06:00     1    17          019          0006         PM2.5 - Local Conditions    1
# 2020-01-22  02:00     3    17          161          3002         PM2.5 - Local Conditions    1
#                                        065          0002         PM2.5 - Local Conditions    1
#                                        083          0117         PM2.5 - Local Conditions    1
#                                        113          2003         PM2.5 - Local Conditions    1
#                                                                                             ..
# 2020-01-11  17:00     3    17          083          0117         PM2.5 - Local Conditions    1
#                                        113          2003         PM2.5 - Local Conditions    1
#                                        115          0013         PM2.5 - Local Conditions    1
#                                        119          3007         Sulfur dioxide              1
# 2020-02-01  05:55     3    17          019          1001         Sulfur dioxide              1
# Name: count, Length: 40385, dtype: int64

# %%
# Get the two Ozone observations from site 9991 on 2020-02-01 at 05:00
mask = (
    (df["date_gmt"] == "2020-02-01") &
    (df["time_gmt"] == "05:00") &
    (df["site_number"] == "9991") &
    (df["parameter"] == "Ozone") &
    (df["detection_limit"] == 0.005) &
    (df["method_code"] == "047") &
    (df["sample_frequency"] == "HOURLY")
)

df[mask]
# Out:
#       state_code county_code site_number parameter_code  poc   latitude  \
# 31682         17         119        9991          44201    1  38.869001
# 32382         17         085        9991          44201    1  42.286900
#
#        longitude  datum parameter  date_local  ... detection_limit  \
# 31682 -89.622816  NAD83     Ozone  2020-01-31  ...           0.005
# 32382 -89.999700  WGS84     Ozone  2020-01-31  ...           0.005
#
#       uncertainty qualifier  method_type                       method  \
# 31682        None      None          FEM  INSTRUMENTAL - ULTRA VIOLET
# 32382        None      None          FEM  INSTRUMENTAL - ULTRA VIOLET
#
#       method_code     state      county date_of_last_change  cbsa_code
# 31682         047  Illinois     Madison          2020-05-01      41180
# 32382         047  Illinois  Jo Daviess          2020-05-01       None
#
# [2 rows x 29 columns]

# %%
# Get the two PM2.5 observations from site 2003 on 2020-01-09 at 19:00
mask = (
    (df["date_gmt"] == "2020-01-09") &
    (df["time_gmt"] == "19:00") &
    (df["state_code"] == "17") &
    (df["county_code"] == "113") &
    (df["site_number"] == "2003") &
    (df["parameter"] == "PM2.5 - Local Conditions") &
    (df["detection_limit"] == 2.0) &
    (df["method_code"] == "183") &
    (df["sample_frequency"] == "HOURLY")
)

df[mask]
# Out:
#       state_code county_code site_number parameter_code  poc   latitude  \
# 20805         17         113        2003          88101    9  40.518735
# 24712         17         113        2003          88101    3  40.518735
#
#        longitude  datum                 parameter  date_local  ...  \
# 20805 -88.996896  WGS84  PM2.5 - Local Conditions  2020-01-09  ...
# 24712 -88.996896  WGS84  PM2.5 - Local Conditions  2020-01-09  ...
#
#       detection_limit uncertainty qualifier  method_type  \
# 20805             2.0        None      None          FEM
# 24712             2.0        None      None          FEM
#
#                                                   method method_code  \
# 20805  Thermo Scientific 5014i or FH62C14-DHS w/VSCC ...         183
# 24712  Thermo Scientific 5014i or FH62C14-DHS w/VSCC ...         183
#
#           state  county date_of_last_change  cbsa_code
# 20805  Illinois  McLean          2020-03-27      14010
# 24712  Illinois  McLean          2020-03-27      14010
#
# [2 rows x 29 columns]

# %%
# load the Illinois acs data
import pandas as pd
import json
acs_json = json.load(open("data/5_year_data/2020/census_state_data_17.json", "r"))
table_groups = {
        "B01003": "Total Population",
        "B02001": "Race",
        "B03003": "Hispanic Origin",
        "B19013": "Median Household Income",
        "B17001": "Poverty",
        "B15003": "Educational Attainment",
        "B01001": "Age Structure"
    }
groups = [acs_json[group] for group in table_groups.keys()]
dfs = []
for group in groups:
    headers = group[0]  # First row is column names
    data = group[1:]     # Rest is actual data
    df = pd.DataFrame(data, columns=headers)
    dfs.append(df)
assert len(dfs[0]) == len(dfs[1]) == len(dfs[2]) == len(dfs[3]) == len(dfs[4]) == len(dfs[5]) == len(dfs[6])

# %%
df_acs = pd.DataFrame()
for i in range(len(dfs)):
    df_acs = pd.merge(df_acs, dfs[i], on=["county", "GEO_ID", "NAME", "state"], how="outer") if not df_acs.empty else dfs[i]
df_acs
# Out:
#     B01003_001E B01003_001EA B01003_001M B01003_001MA          GEO_ID  \
# 0         65670         None  -555555555        *****  0500000US17001
# 1          6011         None  -555555555        *****  0500000US17003
# 2         16520         None  -555555555        *****  0500000US17005
# 3         53293         None  -555555555        *****  0500000US17007
# 4          6599         None  -555555555        *****  0500000US17009
# ..          ...          ...         ...          ...             ...
# 97        55583         None  -555555555        *****  0500000US17195
# 98       689704         None  -555555555        *****  0500000US17197
# 99        66929         None  -555555555        *****  0500000US17199
# 100      283635         None  -555555555        *****  0500000US17201
# 101       38503         None  -555555555        *****  0500000US17203
#
#                             NAME state county B02001_001E B02001_001EA  ...  \
# 0         Adams County, Illinois    17    001       65670         None  ...
# 1     Alexander County, Illinois    17    003        6011         None  ...
# 2          Bond County, Illinois    17    005       16520         None  ...
# 3         Boone County, Illinois    17    007       53293         None  ...
# 4         Brown County, Illinois    17    009        6599         None  ...
# ..                           ...   ...    ...         ...          ...  ...
# 97    Whiteside County, Illinois    17    195       55583         None  ...
# 98         Will County, Illinois    17    197      689704         None  ...
# 99   Williamson County, Illinois    17    199       66929         None  ...
# 100   Winnebago County, Illinois    17    201      283635         None  ...
# 101    Woodford County, Illinois    17    203       38503         None  ...
#
#     B01001_047M B01001_047MA B01001_048E B01001_048EA B01001_048M  \
# 0           263         None         891         None         168
# 1            55         None          98         None          60
# 2            80         None         155         None          59
# 3           195         None         655         None         242
# 4            30         None          44         None          30
# ..          ...          ...         ...          ...         ...
# 97          181         None         817         None         144
# 98          579         None        5512         None         473
# 99          166         None         867         None         200
# 100         366         None        2751         None         292
# 101         144         None         413         None         112
#
#     B01001_048MA B01001_049E B01001_049EA B01001_049M B01001_049MA
# 0           None        1355         None         266         None
# 1           None          78         None          34         None
# 2           None         364         None          93         None
# 3           None         635         None         206         None
# 4           None          91         None          32         None
# ..           ...         ...          ...         ...          ...
# 97          None         963         None         184         None
# 98          None        6475         None         562         None
# 99          None         991         None         226         None
# 100         None        5361         None         409         None
# 101         None         756         None         143         None
#
# [102 rows x 596 columns]

# %%
import requests
print("Fetching metadata for table groups:")
url = "https://api.census.gov/data/2020/acs/acs5/variables.json"
response = requests.get(url)
# Out:
# Fetching metadata for table groups:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 5
#       3 url = "https://api.census.gov/data/2020/acs/acs5/variables.json"
#       4 response = requests.get(url)
# ----> 5 response.json().counts()
#
# AttributeError: 'dict' object has no attribute 'counts'

# %%
len(response.json()["variables"])
# Out:
# 27892

# %%
table_groups = {
        "B01003": "Total Population",
        "B02001": "Race",
        "B03003": "Hispanic Origin",
        "B19013": "Median Household Income",
        "B17001": "Poverty",
        "B15003": "Educational Attainment",
        "B01001": "Age Structure"
    }
response.json()["variables"]
# Out:
# {'for': {'label': "Census API FIPS 'for' clause",
#   'concept': 'Census API Geography Specification',
#   'predicateType': 'fips-for',
#   'group': 'N/A',
#   'limit': 0,
#   'predicateOnly': True},
#  'in': {'label': "Census API FIPS 'in' clause",
#   'concept': 'Census API Geography Specification',
#   'predicateType': 'fips-in',
#   'group': 'N/A',
#   'limit': 0,
#   'predicateOnly': True},
#  'ucgid': {'label': 'Uniform Census Geography Identifier clause',
#   'concept': 'Census API Geography Specification',
#   'predicateType': 'ucgid',
#   'group': 'N/A',
#   'limit': 0,
#   'predicateOnly': True,
#   'hasGeoCollectionSupport': True},
#  'B24022_060E': {'label': 'Estimate!!Total:!!Female:!!Service occupations:!!Food preparation and serving related occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_060EA,B24022_060M,B24022_060MA'},
#  'B19001B_014E': {'label': 'Estimate!!Total:!!$100,000 to $124,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_014EA,B19001B_014M,B19001B_014MA'},
#  'B07007PR_019E': {'label': 'Estimate!!Total:!!Moved from different municipio:!!Foreign born:!!Naturalized U.S. citizen',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_019EA,B07007PR_019M,B07007PR_019MA'},
#  'B19101A_004E': {'label': 'Estimate!!Total:!!$15,000 to $19,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_004EA,B19101A_004M,B19101A_004MA'},
#  'B24022_061E': {'label': 'Estimate!!Total:!!Female:!!Service occupations:!!Building and grounds cleaning and maintenance occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_061EA,B24022_061M,B24022_061MA'},
#  'B19001B_013E': {'label': 'Estimate!!Total:!!$75,000 to $99,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_013EA,B19001B_013M,B19001B_013MA'},
#  'B07007PR_018E': {'label': 'Estimate!!Total:!!Moved from different municipio:!!Foreign born:',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_018EA,B07007PR_018M,B07007PR_018MA'},
#  'B19101A_005E': {'label': 'Estimate!!Total:!!$20,000 to $24,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_005EA,B19101A_005M,B19101A_005MA'},
#  'B24022_062E': {'label': 'Estimate!!Total:!!Female:!!Service occupations:!!Personal care and service occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_062EA,B24022_062M,B24022_062MA'},
#  'B19001B_012E': {'label': 'Estimate!!Total:!!$60,000 to $74,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_012EA,B19001B_012M,B19001B_012MA'},
#  'B01001B_029E': {'label': 'Estimate!!Total:!!Female:!!65 to 74 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_029EA,B01001B_029M,B01001B_029MA'},
#  'B19101A_006E': {'label': 'Estimate!!Total:!!$25,000 to $29,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_006EA,B19101A_006M,B19101A_006MA'},
#  'B20005A_021E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$50,000 to $54,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_021EA,B20005A_021M,B20005A_021MA'},
#  'B07007PR_017E': {'label': 'Estimate!!Total:!!Moved from different municipio:!!Native',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_017EA,B07007PR_017M,B07007PR_017MA'},
#  'B24022_063E': {'label': 'Estimate!!Total:!!Female:!!Sales and office occupations:',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_063EA,B24022_063M,B24022_063MA'},
#  'B07007PR_015E': {'label': 'Estimate!!Total:!!Moved within same municipio:!!Foreign born:!!Not a U.S. citizen',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_015EA,B07007PR_015M,B07007PR_015MA'},
#  'B19001B_011E': {'label': 'Estimate!!Total:!!$50,000 to $59,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_011EA,B19001B_011M,B19001B_011MA'},
#  'B19101A_007E': {'label': 'Estimate!!Total:!!$30,000 to $34,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_007EA,B19101A_007M,B19101A_007MA'},
#  'B20005A_020E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$45,000 to $49,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_020EA,B20005A_020M,B20005A_020MA'},
#  'B07007PR_016E': {'label': 'Estimate!!Total:!!Moved from different municipio:',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_016EA,B07007PR_016M,B07007PR_016MA'},
#  'B24022_064E': {'label': 'Estimate!!Total:!!Female:!!Sales and office occupations:!!Sales and related occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_064EA,B24022_064M,B24022_064MA'},
#  'B19001B_010E': {'label': 'Estimate!!Total:!!$45,000 to $49,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_010EA,B19001B_010M,B19001B_010MA'},
#  'B26209_011E': {'label': 'Estimate!!Total:!!Group quarters population:!!Different address in the United States:',
#   'concept': 'GROUP QUARTERS TYPE (5 TYPES) BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B26209',
#   'limit': 0,
#   'attributes': 'B26209_011EA,B26209_011M,B26209_011MA'},
#  'B01001B_027E': {'label': 'Estimate!!Total:!!Female:!!45 to 54 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_027EA,B01001B_027M,B01001B_027MA'},
#  'B20005A_023E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$65,000 to $74,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_023EA,B20005A_023M,B20005A_023MA'},
#  'B26209_010E': {'label': 'Estimate!!Total:!!Group quarters population:!!Same address',
#   'concept': 'GROUP QUARTERS TYPE (5 TYPES) BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B26209',
#   'limit': 0,
#   'attributes': 'B26209_010EA,B26209_010M,B26209_010MA'},
#  'B24022_065E': {'label': 'Estimate!!Total:!!Female:!!Sales and office occupations:!!Office and administrative support occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_065EA,B24022_065M,B24022_065MA'},
#  'B19101A_001E': {'label': 'Estimate!!Total:',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_001EA,B19101A_001M,B19101A_001MA'},
#  'B01001B_028E': {'label': 'Estimate!!Total:!!Female:!!55 to 64 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_028EA,B01001B_028M,B01001B_028MA'},
#  'B20005A_022E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$55,000 to $64,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_022EA,B20005A_022M,B20005A_022MA'},
#  'B24022_066E': {'label': 'Estimate!!Total:!!Female:!!Natural resources, construction, and maintenance occupations:',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_066EA,B24022_066M,B24022_066MA'},
#  'B01001B_025E': {'label': 'Estimate!!Total:!!Female:!!30 to 34 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_025EA,B01001B_025M,B01001B_025MA'},
#  'B20005A_025E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$100,000 or more',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_025EA,B20005A_025M,B20005A_025MA'},
#  'B19101A_002E': {'label': 'Estimate!!Total:!!Less than $10,000',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_002EA,B19101A_002M,B19101A_002MA'},
#  'B19037E_030E': {'label': 'Estimate!!Total:!!Householder 25 to 44 years:!!$60,000 to $74,999',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_030EA,B19037E_030M,B19037E_030MA'},
#  'B24022_067E': {'label': 'Estimate!!Total:!!Female:!!Natural resources, construction, and maintenance occupations:!!Farming, fishing, and forestry occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_067EA,B24022_067M,B24022_067MA'},
#  'B01001B_026E': {'label': 'Estimate!!Total:!!Female:!!35 to 44 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_026EA,B01001B_026M,B01001B_026MA'},
#  'B19101A_003E': {'label': 'Estimate!!Total:!!$10,000 to $14,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_003EA,B19101A_003M,B19101A_003MA'},
#  'B20005A_024E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$75,000 to $99,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_024EA,B20005A_024M,B20005A_024MA'},
#  'B07007PR_010E': {'label': 'Estimate!!Total:!!Same house 1 year ago:!!Foreign born:!!Not a U.S. citizen',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_010EA,B07007PR_010M,B07007PR_010MA'},
#  'B07004H_002E': {'label': 'Estimate!!Total:!!Same house 1 year ago',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_002EA,B07004H_002M,B07004H_002MA'},
#  'B24136_222E': {'label': 'Estimate!!Total!!Psychiatric and substance abuse hospitals',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_222EA,B24136_222M,B24136_222MA'},
#  'B01001B_022E': {'label': 'Estimate!!Total:!!Female:!!18 and 19 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_022EA,B01001B_022M,B01001B_022MA'},
#  'B20005_028E': {'label': 'Estimate!!Total:!!Male:!!Other:!!With earnings:',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_028EA,B20005_028M,B20005_028MA'},
#  'B01001B_023E': {'label': 'Estimate!!Total:!!Female:!!20 to 24 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_023EA,B01001B_023M,B01001B_023MA'},
#  'B07004H_001E': {'label': 'Estimate!!Total:',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_001EA,B07004H_001M,B07004H_001MA'},
#  'B24136_221E': {'label': 'Estimate!!Total!!General medical and surgical hospitals, and specialty (except psychiatric and substance abuse) hospitals',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_221EA,B24136_221M,B24136_221MA'},
#  'B20005_029E': {'label': 'Estimate!!Total:!!Male:!!Other:!!With earnings:!!$1 to $2,499 or loss',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_029EA,B20005_029M,B20005_029MA'},
#  'B01001B_024E': {'label': 'Estimate!!Total:!!Female:!!25 to 29 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_024EA,B01001B_024M,B01001B_024MA'},
#  'B24136_224E': {'label': 'Estimate!!Total!!Residential care facilities, except skilled nursing facilities',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_224EA,B24136_224M,B24136_224MA'},
#  'B01001B_020E': {'label': 'Estimate!!Total:!!Female:!!10 to 14 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_020EA,B01001B_020M,B01001B_020MA'},
#  'B20005_026E': {'label': 'Estimate!!Total:!!Male:!!Other:',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_026EA,B20005_026M,B20005_026MA'},
#  'B06004E_001E': {'label': 'Estimate!!Total:',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_001EA,B06004E_001M,B06004E_001MA'},
#  'B24136_225E': {'label': 'Estimate!!Total!!Individual and family services',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_225EA,B24136_225M,B24136_225MA'},
#  'B24136_223E': {'label': 'Estimate!!Total!!Nursing care facilities (skilled nursing facilities)',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_223EA,B24136_223M,B24136_223MA'},
#  'B01001B_021E': {'label': 'Estimate!!Total:!!Female:!!15 to 17 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_021EA,B01001B_021M,B01001B_021MA'},
#  'B20005_027E': {'label': 'Estimate!!Total:!!Male:!!Other:!!No earnings',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_027EA,B20005_027M,B20005_027MA'},
#  'B06004E_002E': {'label': 'Estimate!!Total:!!Born in state of residence',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_002EA,B06004E_002M,B06004E_002MA'},
#  'B07007PR_014E': {'label': 'Estimate!!Total:!!Moved within same municipio:!!Foreign born:!!Naturalized U.S. citizen',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_014EA,B07007PR_014M,B07007PR_014MA'},
#  'B07004H_006E': {'label': 'Estimate!!Total:!!Moved from abroad',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_006EA,B07004H_006M,B07004H_006MA'},
#  'B08119_021E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$10,000 to $14,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_021EA,B08119_021M,B08119_021MA'},
#  'B06004E_003E': {'label': 'Estimate!!Total:!!Born in other state in the United States',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_003EA,B06004E_003M,B06004E_003MA'},
#  'B07004H_005E': {'label': 'Estimate!!Total:!!Moved from different state',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_005EA,B07004H_005M,B07004H_005MA'},
#  'B07007PR_013E': {'label': 'Estimate!!Total:!!Moved within same municipio:!!Foreign born:',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_013EA,B07007PR_013M,B07007PR_013MA'},
#  'B19001B_017E': {'label': 'Estimate!!Total:!!$200,000 or more',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_017EA,B19001B_017M,B19001B_017MA'},
#  'B08119_020E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$1 to $9,999 or loss',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_020EA,B08119_020M,B08119_020MA'},
#  'B06004E_004E': {'label': 'Estimate!!Total:!!Native; born outside the United States',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_004EA,B06004E_004M,B06004E_004MA'},
#  'B24136_220E': {'label': 'Estimate!!Total!!Other health care services',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_220EA,B24136_220M,B24136_220MA'},
#  'B07007PR_012E': {'label': 'Estimate!!Total:!!Moved within same municipio:!!Native',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_012EA,B07007PR_012M,B07007PR_012MA'},
#  'B07004H_004E': {'label': 'Estimate!!Total:!!Moved from different county within same state',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_004EA,B07004H_004M,B07004H_004MA'},
#  'B19001B_016E': {'label': 'Estimate!!Total:!!$150,000 to $199,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_016EA,B19001B_016M,B19001B_016MA'},
#  'B06004E_005E': {'label': 'Estimate!!Total:!!Foreign born',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_005EA,B06004E_005M,B06004E_005MA'},
#  'B07007PR_011E': {'label': 'Estimate!!Total:!!Moved within same municipio:',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_011EA,B07007PR_011M,B07007PR_011MA'},
#  'B07004H_003E': {'label': 'Estimate!!Total:!!Moved within same county',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_003EA,B07004H_003M,B07004H_003MA'},
#  'B19001B_015E': {'label': 'Estimate!!Total:!!$125,000 to $149,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_015EA,B19001B_015M,B19001B_015MA'},
#  'B08201_007E': {'label': 'Estimate!!Total:!!1-person household:',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_007EA,B08201_007M,B08201_007MA'},
#  'B16005F_010E': {'label': 'Estimate!!Total:!!Foreign born:!!Speak another language:!!Speak English "very well"',
#   'concept': 'NATIVITY BY LANGUAGE SPOKEN AT HOME BY ABILITY TO SPEAK ENGLISH FOR THE POPULATION 5 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'predicateType': 'int',
#   'group': 'B16005F',
#   'limit': 0,
#   'attributes': 'B16005F_010EA,B16005F_010M,B16005F_010MA'},
#  'B08119_025E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$50,000 to $64,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_025EA,B08119_025M,B08119_025MA'},
#  'B19037E_028E': {'label': 'Estimate!!Total:!!Householder 25 to 44 years:!!$45,000 to $49,999',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_028EA,B19037E_028M,B19037E_028MA'},
#  'B07202_005E': {'label': 'Estimate!!Total:!!Different house in United States 1 year ago:!!Same Micropolitan Statistical Area:!!Moved from principal city',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--MICROPOLITAN STATISTICAL AREA LEVEL IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07202',
#   'limit': 0,
#   'attributes': 'B07202_005EA,B07202_005M,B07202_005MA'},
#  'B24042_022E': {'label': 'Estimate!!Male:!!Educational services, and health care and social assistance:!!Health care and social assistance',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_022EA,B24042_022M,B24042_022MA'},
#  'B20005_020E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$45,000 to $49,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_020EA,B20005_020M,B20005_020MA'},
#  'B08201_008E': {'label': 'Estimate!!Total:!!1-person household:!!No vehicle available',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_008EA,B08201_008M,B08201_008MA'},
#  'B16005F_011E': {'label': 'Estimate!!Total:!!Foreign born:!!Speak another language:!!Speak English less than "very well"',
#   'concept': 'NATIVITY BY LANGUAGE SPOKEN AT HOME BY ABILITY TO SPEAK ENGLISH FOR THE POPULATION 5 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'predicateType': 'int',
#   'group': 'B16005F',
#   'limit': 0,
#   'attributes': 'B16005F_011EA,B16005F_011M,B16005F_011MA'},
#  'B19037E_027E': {'label': 'Estimate!!Total:!!Householder 25 to 44 years:!!$40,000 to $44,999',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_027EA,B19037E_027M,B19037E_027MA'},
#  'B08119_024E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$35,000 to $49,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_024EA,B08119_024M,B08119_024MA'},
#  'B07202_004E': {'label': 'Estimate!!Total:!!Different house in United States 1 year ago:!!Same Micropolitan Statistical Area:',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--MICROPOLITAN STATISTICAL AREA LEVEL IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07202',
#   'limit': 0,
#   'attributes': 'B07202_004EA,B07202_004M,B07202_004MA'},
#  'B24042_023E': {'label': 'Estimate!!Male:!!Arts, entertainment, and recreation, and accommodation and food services:',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_023EA,B24042_023M,B24042_023MA'},
#  'B08201_005E': {'label': 'Estimate!!Total:!!3 vehicles available',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_005EA,B08201_005M,B08201_005MA'},
#  'B26209_009E': {'label': 'Estimate!!Total:!!Group quarters population:',
#   'concept': 'GROUP QUARTERS TYPE (5 TYPES) BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B26209',
#   'limit': 0,
#   'attributes': 'B26209_009EA,B26209_009M,B26209_009MA'},
#  'B08119_023E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$25,000 to $34,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_023EA,B08119_023M,B08119_023MA'},
#  'B24042_020E': {'label': 'Estimate!!Male:!!Educational services, and health care and social assistance:',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_020EA,B24042_020M,B24042_020MA'},
#  'B07202_007E': {'label': 'Estimate!!Total:!!Different house in United States 1 year ago:!!Different Micropolitan Statistical Area:',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--MICROPOLITAN STATISTICAL AREA LEVEL IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07202',
#   'limit': 0,
#   'attributes': 'B07202_007EA,B07202_007M,B07202_007MA'},
#  'B08201_006E': {'label': 'Estimate!!Total:!!4 or more vehicles available',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_006EA,B08201_006M,B08201_006MA'},
#  'B26209_008E': {'label': 'Estimate!!Total:!!Abroad',
#   'concept': 'GROUP QUARTERS TYPE (5 TYPES) BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B26209',
#   'limit': 0,
#   'attributes': 'B26209_008EA,B26209_008M,B26209_008MA'},
#  'B08119_022E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$15,000 to $24,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_022EA,B08119_022M,B08119_022MA'},
#  'B19037E_029E': {'label': 'Estimate!!Total:!!Householder 25 to 44 years:!!$50,000 to $59,999',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_029EA,B19037E_029M,B19037E_029MA'},
#  'B07202_006E': {'label': 'Estimate!!Total:!!Different house in United States 1 year ago:!!Same Micropolitan Statistical Area:!!Moved from remainder of Micropolitan Statistical Area',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--MICROPOLITAN STATISTICAL AREA LEVEL IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07202',
#   'limit': 0,
#   'attributes': 'B07202_006EA,B07202_006M,B07202_006MA'},
#  'B24042_021E': {'label': 'Estimate!!Male:!!Educational services, and health care and social assistance:!!Educational services',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_021EA,B24042_021M,B24042_021MA'},
#  'B08201_003E': {'label': 'Estimate!!Total:!!1 vehicle available',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_003EA,B08201_003M,B08201_003MA'},
#  'B17022_017E': {'label': 'Estimate!!Total:!!Under 1.30:!!Other family:!!Female householder, no spouse present:!!With related children of the householder under 18 years:',
#   'concept': 'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN',
#   'predicateType': 'int',
#   'group': 'B17022',
#   'limit': 0,
#   'attributes': 'B17022_017EA,B17022_017M,B17022_017MA'},
#  'B20005_024E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$75,000 to $99,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_024EA,B20005_024M,B20005_024MA'},
#  'B07202_009E': {'label': 'Estimate!!Total:!!Different house in United States 1 year ago:!!Different Micropolitan Statistical Area:!!Moved from remainder of Micropolitan Statistical Area',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--MICROPOLITAN STATISTICAL AREA LEVEL IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07202',
#   'limit': 0,
#   'attributes': 'B07202_009EA,B07202_009M,B07202_009MA'},
#  'B24136_227E': {'label': 'Estimate!!Total!!Vocational rehabilitation services',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_227EA,B24136_227M,B24136_227MA'},
#  'B17022_018E': {'label': 'Estimate!!Total:!!Under 1.30:!!Other family:!!Female householder, no spouse present:!!With related children of the householder under 18 years:!!Under 5 years only',
#   'concept': 'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN',
#   'predicateType': 'int',
#   'group': 'B17022',
#   'limit': 0,
#   'attributes': 'B17022_018EA,B17022_018M,B17022_018MA'},
#  'B08119_029E': {'label': 'Estimate!!Total:!!Public transportation (excluding taxicab):!!$1 to $9,999 or loss',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_029EA,B08119_029M,B08119_029MA'},
#  'B08201_004E': {'label': 'Estimate!!Total:!!2 vehicles available',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_004EA,B08201_004M,B08201_004MA'},
#  'B20005_025E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$100,000 or more',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_025EA,B20005_025M,B20005_025MA'},
#  'B07202_008E': {'label': 'Estimate!!Total:!!Different house in United States 1 year ago:!!Different Micropolitan Statistical Area:!!Moved from principal city',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--MICROPOLITAN STATISTICAL AREA LEVEL IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07202',
#   'limit': 0,
#   'attributes': 'B07202_008EA,B07202_008M,B07202_008MA'},
#  'B24136_226E': {'label': 'Estimate!!Total!!Community food and housing, and emergency services',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_226EA,B24136_226M,B24136_226MA'},
#  'B08201_001E': {'label': 'Estimate!!Total:',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_001EA,B08201_001M,B08201_001MA'},
#  'B20005_021E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$50,000 to $54,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_021EA,B20005_021M,B20005_021MA'},
#  'B17022_019E': {'label': 'Estimate!!Total:!!Under 1.30:!!Other family:!!Female householder, no spouse present:!!With related children of the householder under 18 years:!!Under 5 years and 5 to 17 years',
#   'concept': 'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN',
#   'predicateType': 'int',
#   'group': 'B17022',
#   'limit': 0,
#   'attributes': 'B17022_019EA,B17022_019M,B17022_019MA'},
#  'B08119_028E': {'label': 'Estimate!!Total:!!Public transportation (excluding taxicab):',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_028EA,B08119_028M,B08119_028MA'},
#  'B08119_027E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$75,000 or more',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_027EA,B08119_027M,B08119_027MA'},
#  'B20005_022E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$55,000 to $64,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_022EA,B20005_022M,B20005_022MA'},
#  'B24136_229E': {'label': 'Estimate!!Total!!Performing arts companies',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_229EA,B24136_229M,B24136_229MA'},
#  'B08201_002E': {'label': 'Estimate!!Total:!!No vehicle available',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_002EA,B08201_002M,B08201_002MA'},
#  'B08119_026E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$65,000 to $74,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_026EA,B08119_026M,B08119_026MA'},
#  'B20005_023E': {'label': 'Estimate!!Total:!!Male:!!Worked full-time, year-round in the past 12 months:!!With earnings:!!$65,000 to $74,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_023EA,B20005_023M,B20005_023MA'},
#  'B24136_228E': {'label': 'Estimate!!Total!!Child day care services',
#   'concept': 'DETAILED INDUSTRY FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24136',
#   'limit': 0,
#   'attributes': 'B24136_228EA,B24136_228M,B24136_228MA'},
#  'B26209_003E': {'label': 'Estimate!!Total:!!Different address in the United States:',
#   'concept': 'GROUP QUARTERS TYPE (5 TYPES) BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B26209',
#   'limit': 0,
#   'attributes': 'B26209_003EA,B26209_003M,B26209_003MA'},
#  'B17022_013E': {'label': 'Estimate!!Total:!!Under 1.30:!!Other family:!!Male householder, no spouse present:!!With related children of the householder under 18 years:!!Under 5 years and 5 to 17 years',
#   'concept': 'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN',
#   'predicateType': 'int',
#   'group': 'B17022',
#   'limit': 0,
#   'attributes': 'B17022_013EA,B17022_013M,B17022_013MA'},
#  'B24022_068E': {'label': 'Estimate!!Total:!!Female:!!Natural resources, construction, and maintenance occupations:!!Construction and extraction occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_068EA,B24022_068M,B24022_068MA'},
#  'B20005A_027E': {'label': 'Estimate!!Total:!!Male:!!Other:!!No earnings',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_027EA,B20005A_027M,B20005A_027MA'},
#  'B19037E_020E': {'label': 'Estimate!!Total:!!Householder 25 to 44 years:!!Less than $10,000',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_020EA,B19037E_020M,B19037E_020MA'},
#  'B17022_014E': {'label': 'Estimate!!Total:!!Under 1.30:!!Other family:!!Male householder, no spouse present:!!With related children of the householder under 18 years:!!5 to 17 years only',
#   'concept': 'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN',
#   'predicateType': 'int',
#   'group': 'B17022',
#   'limit': 0,
#   'attributes': 'B17022_014EA,B17022_014M,B17022_014MA'},
#  'B26209_002E': {'label': 'Estimate!!Total:!!Same address',
#   'concept': 'GROUP QUARTERS TYPE (5 TYPES) BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B26209',
#   'limit': 0,
#   'attributes': 'B26209_002EA,B26209_002M,B26209_002MA'},
#  'B24022_069E': {'label': 'Estimate!!Total:!!Female:!!Natural resources, construction, and maintenance occupations:!!Installation, maintenance, and repair occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_069EA,B24022_069M,B24022_069MA'},
#  'B20005A_026E': {'label': 'Estimate!!Total:!!Male:!!Other:',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_026EA,B20005A_026M,B20005A_026MA'},
#  'B17022_015E': {'label': 'Estimate!!Total:!!Under 1.30:!!Other family:!!Male householder, no spouse present:!!No related children of the householder under 18 years',
#   'concept': 'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN',
#   'predicateType': 'int',
#   'group': 'B17022',
#   'limit': 0,
#   'attributes': 'B17022_015EA,B17022_015M,B17022_015MA'},
#  'B26209_001E': {'label': 'Estimate!!Total:',
#   'concept': 'GROUP QUARTERS TYPE (5 TYPES) BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B26209',
#   'limit': 0,
#   'attributes': 'B26209_001EA,B26209_001M,B26209_001MA'},
#  'B24042_028E': {'label': 'Estimate!!Female:',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_028EA,B24042_028M,B24042_028MA'},
#  'B20005A_029E': {'label': 'Estimate!!Total:!!Male:!!Other:!!With earnings:!!$1 to $2,499 or loss',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_029EA,B20005A_029M,B20005A_029MA'},
# ...
#  'B08519_024E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$35,000 to $49,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'predicateType': 'int',
#   'group': 'B08519',
#   'limit': 0,
#   'attributes': 'B08519_024EA,B08519_024M,B08519_024MA'},
#  'B25125_022E': {'label': 'Estimate!!Total:!!Owner occupied:!!Householder 65 years and over:!!50 or more',
#   'concept': 'TENURE BY AGE OF HOUSEHOLDER BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B25125',
#   'limit': 0,
#   'attributes': 'B25125_022EA,B25125_022M,B25125_022MA'},
#  'B20005_041E': {'label': 'Estimate!!Total:!!Male:!!Other:!!With earnings:!!$35,000 to $39,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_041EA,B20005_041M,B20005_041MA'},
#  'B08201_029E': {'label': 'Estimate!!Total:!!4-or-more-person household:!!3 vehicles available',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_029EA,B08201_029M,B08201_029MA'},
#  'B02014_011E': {'label': 'Estimate!!Total:!!American Indian tribes, specified:!!Chippewa',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_011EA,B02014_011M,B02014_011MA'},
#  'B08119_047E': {'label': 'Estimate!!Total:!!Taxicab, motorcycle, bicycle, or other means:!!$1 to $9,999 or loss',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_047EA,B08119_047M,B08119_047MA'},
#  'B19037E_006E': {'label': 'Estimate!!Total:!!Householder under 25 years:!!$20,000 to $24,999',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_006EA,B19037E_006M,B19037E_006MA'},
#  'B08519_023E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$25,000 to $34,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'predicateType': 'int',
#   'group': 'B08519',
#   'limit': 0,
#   'attributes': 'B08519_023EA,B08519_023M,B08519_023MA'},
#  'B14004_023E': {'label': 'Estimate!!Total:!!Female:!!Enrolled in public college or graduate school:!!35 years and over',
#   'concept': 'SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B14004',
#   'limit': 0,
#   'attributes': 'B14004_023EA,B14004_023M,B14004_023MA'},
#  'B24042_044E': {'label': 'Estimate!!Female:!!Professional, scientific, and management, and administrative, and waste management services:!!Professional, scientific, and technical services',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_044EA,B24042_044M,B24042_044MA'},
#  'B25003C_002E': {'label': 'Estimate!!Total:!!Owner occupied',
#   'concept': 'TENURE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B25003C',
#   'limit': 0,
#   'attributes': 'B25003C_002EA,B25003C_002M,B25003C_002MA'},
#  'B25125_023E': {'label': 'Estimate!!Total:!!Owner occupied:!!Householder 65 years and over:!!Mobile home, boat, RV, van, etc.',
#   'concept': 'TENURE BY AGE OF HOUSEHOLDER BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B25125',
#   'limit': 0,
#   'attributes': 'B25125_023EA,B25125_023M,B25125_023MA'},
#  'B20005_042E': {'label': 'Estimate!!Total:!!Male:!!Other:!!With earnings:!!$40,000 to $44,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_042EA,B20005_042M,B20005_042MA'},
#  'B19037E_005E': {'label': 'Estimate!!Total:!!Householder under 25 years:!!$15,000 to $19,999',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_005EA,B19037E_005M,B19037E_005MA'},
#  'B02014_010E': {'label': 'Estimate!!Total:!!American Indian tribes, specified:!!Chickasaw',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_010EA,B02014_010M,B02014_010MA'},
#  'B08119_046E': {'label': 'Estimate!!Total:!!Taxicab, motorcycle, bicycle, or other means:',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_046EA,B08119_046M,B08119_046MA'},
#  'B08519_022E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$15,000 to $24,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'predicateType': 'int',
#   'group': 'B08519',
#   'limit': 0,
#   'attributes': 'B08519_022EA,B08519_022M,B08519_022MA'},
#  'B24042_045E': {'label': 'Estimate!!Female:!!Professional, scientific, and management, and administrative, and waste management services:!!Management of companies and enterprises',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_045EA,B24042_045M,B24042_045MA'},
#  'B14004_024E': {'label': 'Estimate!!Total:!!Female:!!Enrolled in private college or graduate school:',
#   'concept': 'SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B14004',
#   'limit': 0,
#   'attributes': 'B14004_024EA,B14004_024M,B14004_024MA'},
#  'B02014_018E': {'label': 'Estimate!!Total:!!American Indian tribes, specified:!!Delaware',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_018EA,B02014_018M,B02014_018MA'},
#  'B08201_027E': {'label': 'Estimate!!Total:!!4-or-more-person household:!!1 vehicle available',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_027EA,B08201_027M,B08201_027MA'},
#  'B02019_009E': {'label': 'Estimate!!Total Groups Tallied:!!Melanesian:!!Fijian',
#   'concept': 'NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE OR IN ANY COMBINATION BY SELECTED GROUPS',
#   'predicateType': 'int',
#   'group': 'B02019',
#   'limit': 0,
#   'attributes': 'B02019_009EA,B02019_009M,B02019_009MA'},
#  'B25125_029E': {'label': 'Estimate!!Total:!!Renter occupied:!!Householder 15 to 34 years:!!20 to 49',
#   'concept': 'TENURE BY AGE OF HOUSEHOLDER BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B25125',
#   'limit': 0,
#   'attributes': 'B25125_029EA,B25125_029M,B25125_029MA'},
#  'B20005_048E': {'label': 'Estimate!!Total:!!Male:!!Other:!!With earnings:!!$100,000 or more',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_048EA,B20005_048M,B20005_048MA'},
#  'B19037E_008E': {'label': 'Estimate!!Total:!!Householder under 25 years:!!$30,000 to $34,999',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_008EA,B19037E_008M,B19037E_008MA'},
#  'B24042_042E': {'label': 'Estimate!!Female:!!Finance and insurance, and real estate, and rental and leasing:!!Real estate and rental and leasing',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_042EA,B24042_042M,B24042_042MA'},
#  'B08519_021E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$10,000 to $14,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'predicateType': 'int',
#   'group': 'B08519',
#   'limit': 0,
#   'attributes': 'B08519_021EA,B08519_021M,B08519_021MA'},
#  'B06007PR_038E': {'label': 'Estimate!!Total:!!Foreign born:!!Speak other languages:',
#   'concept': 'PLACE OF BIRTH BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B06007PR',
#   'limit': 0,
#   'attributes': 'B06007PR_038EA,B06007PR_038M,B06007PR_038MA'},
#  'B02019_008E': {'label': 'Estimate!!Total Groups Tallied:!!Micronesian:!!Other Micronesian',
#   'concept': 'NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE OR IN ANY COMBINATION BY SELECTED GROUPS',
#   'predicateType': 'int',
#   'group': 'B02019',
#   'limit': 0,
#   'attributes': 'B02019_008EA,B02019_008M,B02019_008MA'},
#  'B08201_028E': {'label': 'Estimate!!Total:!!4-or-more-person household:!!2 vehicles available',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_028EA,B08201_028M,B08201_028MA'},
#  'B02014_017E': {'label': 'Estimate!!Total:!!American Indian tribes, specified:!!Crow',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_017EA,B02014_017M,B02014_017MA'},
#  'B02014_016E': {'label': 'Estimate!!Total:!!American Indian tribes, specified:!!Creek',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_016EA,B02014_016M,B02014_016MA'},
#  'B20005_049E': {'label': 'Estimate!!Total:!!Female:',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_049EA,B20005_049M,B20005_049MA'},
#  'B19037E_007E': {'label': 'Estimate!!Total:!!Householder under 25 years:!!$25,000 to $29,999',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_007EA,B19037E_007M,B19037E_007MA'},
#  'B08519_020E': {'label': 'Estimate!!Total:!!Car, truck, or van - carpooled:!!$1 to $9,999 or loss',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'predicateType': 'int',
#   'group': 'B08519',
#   'limit': 0,
#   'attributes': 'B08519_020EA,B08519_020M,B08519_020MA'},
#  'B06007PR_039E': {'label': 'Estimate!!Total:!!Foreign born:!!Speak other languages:!!Speak English "very well"',
#   'concept': 'PLACE OF BIRTH BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B06007PR',
#   'limit': 0,
#   'attributes': 'B06007PR_039EA,B06007PR_039M,B06007PR_039MA'},
#  'B24042_043E': {'label': 'Estimate!!Female:!!Professional, scientific, and management, and administrative, and waste management services:',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_043EA,B24042_043M,B24042_043MA'},
#  'B08201_025E': {'label': 'Estimate!!Total:!!4-or-more-person household:',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_025EA,B08201_025M,B08201_025MA'},
#  'B02019_007E': {'label': 'Estimate!!Total Groups Tallied:!!Micronesian:!!Marshallese',
#   'concept': 'NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE OR IN ANY COMBINATION BY SELECTED GROUPS',
#   'predicateType': 'int',
#   'group': 'B02019',
#   'limit': 0,
#   'attributes': 'B02019_007EA,B02019_007M,B02019_007MA'},
#  'B24116_448E': {'label': 'Estimate!!Total:!!Automotive service technicians and mechanics',
#   'concept': 'DETAILED OCCUPATION FOR THE CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24116',
#   'limit': 0,
#   'attributes': 'B24116_448EA,B24116_448M,B24116_448MA'},
#  'B14004_028E': {'label': 'Estimate!!Total:!!Female:!!Enrolled in private college or graduate school:!!35 years and over',
#   'concept': 'SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B14004',
#   'limit': 0,
#   'attributes': 'B14004_028EA,B14004_028M,B14004_028MA'},
#  'B25125_026E': {'label': 'Estimate!!Total:!!Renter occupied:!!Householder 15 to 34 years:!!1, detached  or attached',
#   'concept': 'TENURE BY AGE OF HOUSEHOLDER BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B25125',
#   'limit': 0,
#   'attributes': 'B25125_026EA,B25125_026M,B25125_026MA'},
#  'B02014_015E': {'label': 'Estimate!!Total:!!American Indian tribes, specified:!!Cree',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_015EA,B02014_015M,B02014_015MA'},
#  'B20005_046E': {'label': 'Estimate!!Total:!!Male:!!Other:!!With earnings:!!$65,000 to $74,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_046EA,B20005_046M,B20005_046MA'},
#  'B24042_040E': {'label': 'Estimate!!Female:!!Finance and insurance, and real estate, and rental and leasing:',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24042',
#   'limit': 0,
#   'attributes': 'B24042_040EA,B24042_040M,B24042_040MA'},
#  'B14004_027E': {'label': 'Estimate!!Total:!!Female:!!Enrolled in private college or graduate school:!!25 to 34 years',
#   'concept': 'SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B14004',
#   'limit': 0,
#   'attributes': 'B14004_027EA,B14004_027M,B14004_027MA'},
#  ...}

# %%
relevant_variables = {}
variables_metadata = response.json()["variables"]
for variable_code, variable_info in variables_metadata.items():
    if variable_info.get("group", "") in table_groups.keys():
        relevant_variables[variable_code] = variable_info

# %%
len(relevant_variables)
